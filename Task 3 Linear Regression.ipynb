# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
df = pd.read_csv("Housing.csv")
df.dropna(inplace=True)
X = df[['area']]   
y = df['price']     
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_test_pred = model.predict(X_test)
y_pred_full = model.predict(X)
mae = mean_absolute_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)
print("Model Evaluation:")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print("\nModel Coefficients:")
print(f"Intercept: {model.intercept_:.2f}")
print(f"Slope for 'area': {model.coef_[0]:.2f}")
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['area'], y=df['price'], color='blue', label='Actual Data')
plt.plot(df['area'], y_pred_full, color='red', linewidth=2, label='Regression Line')
plt.xlabel("Area (sqft)")
plt.ylabel("Price")
plt.title("Simple Linear Regression: Area vs Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model Evaluation:
# Mean Absolute Error (MAE): 1026553.77
# Mean Squared Error (MSE): 1997672371756.09
# R² Score: 0.31
#
# Model Coefficients:
# Intercept: 2329244.91
# Slope for 'area': 475.27
